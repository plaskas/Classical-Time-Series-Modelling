# %% [markdown]
# # Classical Time-Series Modelling Methods

# %% [markdown]
# Exploring machine learning time-series methods using StatsModels library and US unemployment data generated by BLS.

# %%
import pandas as pd

#importing unemployment data
data = pd.read_csv('./BLS Data Series.csv')
data.head()
# Out:
#    Year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 0  2010  9.8  9.8  9.9  9.9  9.6  9.4  9.4  9.5  9.5  9.4  9.8  9.3
# 1  2011  9.1  9.0  9.0  9.1  9.0  9.1  9.0  9.0  9.0  8.8  8.6  8.5
# 2  2012  8.3  8.3  8.2  8.2  8.2  8.2  8.2  8.1  7.8  7.8  7.7  7.9
# 3  2013  8.0  7.7  7.5  7.6  7.5  7.5  7.3  7.2  7.2  7.2  6.9  6.7
# 4  2014  6.6  6.7  6.7  6.2  6.3  6.1  6.2  6.1  5.9  5.7  5.8  5.6

# %%
unem = pd.melt(data, id_vars='Year', var_name='Month', value_name='Unemployment')
unem['Date'] = unem['Month'] + " " + unem['Year'].map(str)
unem['Date'] = pd.to_datetime(unem.Date, format='%b%Y')
unem.drop(['Year','Month'], axis=1, inplace=True)
unem.sort_values(by='Date', inplace=True)
# unem.index = pd.DatetimeIndex(unem['Date']).to_period(freq='M')
# unem.drop(['Date'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     447             try:
# --> 448                 values, tz = conversion.datetime_to_datetime64(arg)
#     449                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-93362e0d98ec> in <module>
#       1 unem = pd.melt(data, id_vars='Year', var_name='Month', value_name='Unemployment')
#       2 unem['Date'] = unem['Month'] + " " + unem['Year'].map(str)
# ----> 3 unem['Date'] = pd.to_datetime(unem.Date, format='%b%Y')
#       4 unem.drop(['Year','Month'], axis=1, inplace=True)
#       5 unem.sort_values(by='Date', inplace=True)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     776             result = arg.map(cache_array)
#     777         else:
# --> 778             values = convert_listlike(arg._values, True, format)
#     779             result = arg._constructor(values, index=arg.index, name=arg.name)
#     780     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     449                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     450             except (ValueError, TypeError):
# --> 451                 raise e
#     452
#     453     if result is None:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     414                 try:
#     415                     result, timezones = array_strptime(
# --> 416                         arg, format, exact=exact, errors=errors
#     417                     )
#     418                     if "%Z" in format or "%z" in format:
#
# pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data 'Jan 2010' does not match format '%b%Y' (match)

# %%
unem.dropna(axis=0, inplace=True)

# %%
unem.head()
# Out:
#     Unemployment       Date
# 0            9.8 2010-01-01
# 11           9.8 2010-02-01
# 22           9.9 2010-03-01
# 33           9.9 2010-04-01
# 44           9.6 2010-05-01

# %%
unem.to_csv('unemployment.csv')

# %% [markdown]
# ### Autocorrelation

# %% [markdown]
# Autocorrelation is the measure of how related present values in a time-series are to their presceding values.

# %%
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf

import matplotlib.pyplot as plt

# %%
#Unemployment Difference calculates the difference between the current and 1 preceding value
unem_diff = unem['Unemployment'].diff()
unem_diff.dropna(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12,5))
plot_acf(unem_diff.values, lags=12, ax=ax, title='Autocorrelation of US Unemployment')
plt.show()

# %% [markdown]
# ### Autoregression
#
# An Autoregression model predicts the next step in a time-series set of data, based on previous steps.

# %%
from statsmodels.tsa.ar_model import AutoReg
import plotly.express as px
import plotly.graph_objects as go

# %%
unem['Unemployment'].plot(lw=2.5, figsize=(12,5), title='US Unemployment Rate/Month')

# %%
AR_join.reset_index(inplace=True)
AR_join.head()
# Out:
#       Date  Unemployment     y-hat
# 0  2010-01           9.8       NaN
# 1  2010-02           9.8  9.666622
# 2  2010-03           9.9  9.666622
# 3  2010-04           9.9  9.761863
# 4  2010-05           9.6  9.761863

# %%
#fitting model
AR = AutoReg(unem, lags=1)
AR_fit = AR.fit()

#predictions
yhat = AR_fit.predict()

#Plotting AR with original data
# fig, ax = plt.subplots(figsize=(12,5))
# ax.plot(yhat, color='grey')
# ax.plot(unem)
# plt.show()

AR_join = pd.DataFrame.join(unem, yhat.to_frame(name='y-hat'))

fig = go.Figure()

fig.add_trace(go.Scatter(y=AR_join['Unemployment'], name='Raw-Data',
                         line=dict(color='grey', dash='dash')))

fig.add_trace(go.Scatter(y=AR_join['y-hat'], name='Predicted Data',
                         line=dict(color='red')))

fig.update_layout(title='US Unemployment with Autoregression',
                  xaxis_title='Month',
                  yaxis_title='Unemployment %')

fig.show()
